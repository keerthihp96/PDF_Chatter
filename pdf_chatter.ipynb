# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pip install langchain langchain-community langchain-core -q
# Out:
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import langchain

# %%
langchain.__version__
# Out:
# '0.3.28'

# %%
pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2

# %%
PyPDF2.__version__
# Out:
# '3.0.1'

# %%
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# %%
pdf_path = "sample_report.pdf"

# %%
pdf_text = extract_text_from_pdf(pdf_path)

# %%
pdf_text
# Out:
# 'TechCorp Annual Report 2025\n Innovation \x7f Growth \x7f Excellence\n \nExecutive Summary\nTechCorp delivered exceptional performance in 2025, achieving record-breaking revenue growth of 42%\nyear-over-year. Our AI-powered product suite gained significant market traction, with over 5 million active users\nacross 80+ countries. Strategic investments in R&D; and talent acquisition have positioned us strongly for\ncontinued expansion in 2026.\nKey Highlights\nMetric\n2024\n2025\nGrowth\nTotal Revenue\n$48.2M\n$68.5M\n+42%\nActive Users\n2.1M\n5.3M\n+152%\nEnterprise Clients\n320\n890\n+178%\nCountries\n45\n83\n+84%\nEmployee Count\n410\n780\n+90%\nProduct Overview\nOur flagship products continued to dominate their respective markets in 2025. The launch of TechCorp AI\nStudio in Q2 was met with overwhelming demand, generating $12M in revenue within its first quarter alone.\nMeanwhile, our cloud infrastructure platform surpassed 99.99% uptime SLA commitments throughout the year.\nQuarte
# ...

# %%
from langchain import OpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

# %%
template = """
You are an expert AI assistant.Use the information provided for answering the questions.

context : {context}

Question : {question}

Answer: 
"""

# %%
prompt = PromptTemplate(input_variables=["context", "question"], template=template)

# %%
pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
llm = OpenAI(api_key=openai_api_key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 llm = OpenAI(api_key=openai_api_key)
#
# NameError: name 'OpenAI' is not defined

# %%
qa_chain = LLMChain(llm=llm,prompt = prompt)
# Out:
# /var/folders/d6/zd10xfgn24x19wdn5wqqwblw0000gn/T/ipykernel_89705/3454413450.py:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   qa_chain = LLMChain(llm=llm,prompt = prompt)

# %%
def answer_question(pdf_text, question):
    answer = qa_chain.run(context = pdf_text, question =question)
    return answer

# %%
question = "what is the main topic discussed in the document?"

# %%
answer = answer_question(pdf_text, question)
# Out:
# /var/folders/d6/zd10xfgn24x19wdn5wqqwblw0000gn/T/ipykernel_89705/2291027460.py:2: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   answer = qa_chain.run(context = pdf_text, question =question)
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 answer = answer_question(pdf_text, question)
#
# Cell In[24], line 2, in answer_question(pdf_text, question)
#       1 def answer_question(pdf_text, question):
# ----> 2     answer = qa_chain.run(context = pdf_text, question =question)
#       3     return answer
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/_api/deprecation.py:193, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     191     warned = True
#     192     emit_warning()
# ...

# %%
print(answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(answer)
#
# NameError: name 'answer' is not defined
